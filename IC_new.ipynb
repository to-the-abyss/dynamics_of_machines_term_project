# %% [markdown]
# # Dynamic Analysis of an IC engine

# %%
import sympy as sym

# %%
t, lag, k ,m2,ma, kr,m4,mb,l2,l3,ev,f1,A,P= sym.symbols('t, lag, k ,m_2,m_a k_r,m_4,m_b,l_2,l_3,e_v,f_1,A,P')

# %%
theta = sym.Function('theta')(t)
sd = sym.Function('s_d')(t)
co = sym.Function('c_o')(theta,sd)

v1 = sym.diff(theta,t)
v2 = sym.diff(sd,t)

zf = (l2*sym.cos(theta)-sd)**2 + (l2*sym.sin(theta)-ev)**2

display(v1,v2,zf)
# Out:
# Derivative(theta(t), t)
# Derivative(s_d(t), t)
# (-e_v + l_2*sin(theta(t)))**2 + (l_2*cos(theta(t)) - s_d(t))**2

# %%
lag  = 0.5*m2*kr**2*v1**2 + 0.5*ma*l2**2*v1**2 + 0.5*(m4+mb)*v2**2-0.5*k*co**2
lag
# Out:
# -0.5*k*c_o(theta(t), s_d(t))**2 + 0.5*k_r**2*m_2*Derivative(theta(t), t)**2 + 0.5*l_2**2*m_a*Derivative(theta(t), t)**2 + (0.5*m_4 + 0.5*m_b)*Derivative(s_d(t), t)**2

# %%
a1 = sym.Array([theta,sd])
b1 = sym.Array([v1,v2])
c1 = sym.Array([sym.diff(v1,t),sym.diff(v2,t)])
d1 = sym.Array([sym.diff(co,a1[0]), sym.diff(co,a1[1])])
e1 = sym.Array([sym.diff(zf,a1[0]),sym.diff(zf,a1[1])])
display(a1,b1,c1,d1,e1)
# Out:
# [theta(t), s_d(t)]
# [Derivative(theta(t), t), Derivative(s_d(t), t)]
# [Derivative(theta(t), (t, 2)), Derivative(s_d(t), (t, 2))]
# [Derivative(c_o(theta(t), s_d(t)), theta(t)), Derivative(c_o(theta(t), s_d(t)), s_d(t))]
# [2*l_2*(-e_v + l_2*sin(theta(t)))*cos(theta(t)) - 2*l_2*(l_2*cos(theta(t)) - s_d(t))*sin(theta(t)), -2*l_2*cos(theta(t)) + 2*s_d(t)]

# %%
def udef(f,a): return sym.diff(f,a)
def mdel1(f,a): return[udef(f,a[i]) for i in range(len(a))]

# %%
eqn = sym.diff(sym.Array(mdel1(lag,b1)),t) - sym.Array(mdel1(lag,a1)) + sym.Array([-f1,7000000**(sym.sin((theta-sym.pi)/2))*A])
eqn
# Out:
# [-f_1 + 1.0*k*c_o(theta(t), s_d(t))*Derivative(c_o(theta(t), s_d(t)), theta(t)) + 1.0*k_r**2*m_2*Derivative(theta(t), (t, 2)) + 1.0*l_2**2*m_a*Derivative(theta(t), (t, 2)), 1.0*k*c_o(theta(t), s_d(t))*Derivative(c_o(theta(t), s_d(t)), s_d(t)) + (m_4 + m_b)*Derivative(s_d(t), (t, 2)) + A/7000000**cos(theta(t)/2)]

# %%
eqarr = sym.Array([sym.Eq(eqn[i],0) for i in range(len(a1))])
eqarr
# Out:
# [Eq(-f_1 + 1.0*k*c_o(theta(t), s_d(t))*Derivative(c_o(theta(t), s_d(t)), theta(t)) + 1.0*k_r**2*m_2*Derivative(theta(t), (t, 2)) + 1.0*l_2**2*m_a*Derivative(theta(t), (t, 2)), 0), Eq(1.0*k*c_o(theta(t), s_d(t))*Derivative(c_o(theta(t), s_d(t)), s_d(t)) + (m_4 + m_b)*Derivative(s_d(t), (t, 2)) + A/7000000**cos(theta(t)/2), 0)]

# %%
d2w = sym.Array(sym.linsolve(eqarr,c1))[0]
d2w1 = d2w.subs([(d1[0],e1[0]/(2*l3)), (d1[1],e1[1]/(2*l3))])
d2w1
# Out:
# [1.0*f_1/(1.0*k_r**2*m_2 + 1.0*l_2**2*m_a) - 0.5*k*(2*l_2*(-e_v + l_2*sin(theta(t)))*cos(theta(t)) - 2*l_2*(l_2*cos(theta(t)) - s_d(t))*sin(theta(t)))*c_o(theta(t), s_d(t))/(l_3*(1.0*k_r**2*m_2 + 1.0*l_2**2*m_a)), -0.5*7000000**cos(theta(t)/2)*k*(-2*l_2*cos(theta(t)) + 2*s_d(t))*c_o(theta(t), s_d(t))/(l_3*(1.0*7000000**cos(theta(t)/2)*m_4 + 1.0*7000000**cos(theta(t)/2)*m_b)) - 1.0*A/(1.0*7000000**cos(theta(t)/2)*m_4 + 1.0*7000000**cos(theta(t)/2)*m_b)]

# %%
ceq = sym.diff(zf,theta)*c1[0] + sym.diff(zf,sd)*c1[1] + sym.diff(zf,[theta,2])*b1[0]**2+2*sym.diff(sym.diff(zf,theta),sd)*b1[0]*b1[1]+ sym.diff(zf,[sd,2])*b1[1]**2
ceq1 = ceq.subs([(c1[0],d2w1[0]), (c1[1],d2w1[1])])
ceq1
# Out:
# 2*l_2*(l_2*sin(theta(t))**2 + l_2*cos(theta(t))**2 + (e_v - l_2*sin(theta(t)))*sin(theta(t)) - (l_2*cos(theta(t)) - s_d(t))*cos(theta(t)))*Derivative(theta(t), t)**2 + 4*l_2*sin(theta(t))*Derivative(s_d(t), t)*Derivative(theta(t), t) + (1.0*f_1/(1.0*k_r**2*m_2 + 1.0*l_2**2*m_a) - 0.5*k*(2*l_2*(-e_v + l_2*sin(theta(t)))*cos(theta(t)) - 2*l_2*(l_2*cos(theta(t)) - s_d(t))*sin(theta(t)))*c_o(theta(t), s_d(t))/(l_3*(1.0*k_r**2*m_2 + 1.0*l_2**2*m_a)))*(2*l_2*(-e_v + l_2*sin(theta(t)))*cos(theta(t)) - 2*l_2*(l_2*cos(theta(t)) - s_d(t))*sin(theta(t))) + (-2*l_2*cos(theta(t)) + 2*s_d(t))*(-0.5*7000000**cos(theta(t)/2)*k*(-2*l_2*cos(theta(t)) + 2*s_d(t))*c_o(theta(t), s_d(t))/(l_3*(1.0*7000000**cos(theta(t)/2)*m_4 + 1.0*7000000**cos(theta(t)/2)*m_b)) - 1.0*A/(1.0*7000000**cos(theta(t)/2)*m_4 + 1.0*7000000**cos(theta(t)/2)*m_b)) + 2*Derivative(s_d(t), t)**2

# %%
kv = sym.solve(ceq1,k)[0]

# %%
kv
# Out:
# l_3*(-7000000.0**cos(0.5*theta(t))*e_v*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*cos(theta(t)) - 7000000.0**cos(0.5*theta(t))*e_v*f_1*l_2**3*m_a*(m_4 + m_b)**2*cos(theta(t)) + 7000000.0**cos(0.5*theta(t))*e_v*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*sin(theta(t))*Derivative(theta(t), t)**2 + 7000000.0**cos(0.5*theta(t))*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*s_d(t)*sin(theta(t)) + 7000000.0**cos(0.5*theta(t))*f_1*l_2**3*m_a*(m_4 + m_b)**2*s_d(t)*sin(theta(t)) + 7000000.0**cos(0.5*theta(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*s_d(t)*cos(theta(t))*Derivative(theta(t), t)**2 + 2.0*7000000.0**cos(0.5*theta(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*sin(theta(t))*Derivative(s_d(t), t)*Derivative(theta(t), t) + 7000000.0**cos(0.5*theta(t))*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*Derivative(s_d(t), t)**2 + A*l_2*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*cos(theta(t)) + A*l_2*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*cos(theta(t)) - A*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*s_d(t) - A*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*s_d(t))/(7000000.0**cos(0.5*theta(t))*(k_r**2*l_2**2*m_2*(m_4 + m_b)**2*(e_v*cos(theta(t)) - s_d(t)*sin(theta(t)))**2 + l_2**4*m_a*(m_4 + m_b)**2*(e_v*cos(theta(t)) - s_d(t)*sin(theta(t)))**2 + m_4*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(theta(t)) - s_d(t))**2 + m_b*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(theta(t)) - s_d(t))**2)*c_o(theta(t), s_d(t)))

# %%
d2w2 = d2w1.subs(k,kv)
d2w2
# Out:
# [1.0*f_1/(1.0*k_r**2*m_2 + 1.0*l_2**2*m_a) - 0.5*(2*l_2*(-e_v + l_2*sin(theta(t)))*cos(theta(t)) - 2*l_2*(l_2*cos(theta(t)) - s_d(t))*sin(theta(t)))*(-7000000.0**cos(0.5*theta(t))*e_v*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*cos(theta(t)) - 7000000.0**cos(0.5*theta(t))*e_v*f_1*l_2**3*m_a*(m_4 + m_b)**2*cos(theta(t)) + 7000000.0**cos(0.5*theta(t))*e_v*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*sin(theta(t))*Derivative(theta(t), t)**2 + 7000000.0**cos(0.5*theta(t))*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*s_d(t)*sin(theta(t)) + 7000000.0**cos(0.5*theta(t))*f_1*l_2**3*m_a*(m_4 + m_b)**2*s_d(t)*sin(theta(t)) + 7000000.0**cos(0.5*theta(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*s_d(t)*cos(theta(t))*Derivative(theta(t), t)**2 + 2.0*7000000.0**cos(0.5*theta(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*sin(theta(t))*Derivative(s_d(t), t)*Derivative(theta(t), t) + 7000000.0**cos(0.5*theta(t))*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*Derivative(s_d(t), t)**2 + A*l_2*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*cos(theta(t)) + A*l_2*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*cos(theta(t)) - A*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*s_d(t) - A*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*s_d(t))/(7000000.0**cos(0.5*theta(t))*(1.0*k_r**2*m_2 + 1.0*l_2**2*m_a)*(k_r**2*l_2**2*m_2*(m_4 + m_b)**2*(e_v*cos(theta(t)) - s_d(t)*sin(theta(t)))**2 + l_2**4*m_a*(m_4 + m_b)**2*(e_v*cos(theta(t)) - s_d(t)*sin(theta(t)))**2 + m_4*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(theta(t)) - s_d(t))**2 + m_b*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(theta(t)) - s_d(t))**2)), -0.5*7000000**cos(theta(t)/2)*(-2*l_2*cos(theta(t)) + 2*s_d(t))*(-7000000.0**cos(0.5*theta(t))*e_v*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*cos(theta(t)) - 7000000.0**cos(0.5*theta(t))*e_v*f_1*l_2**3*m_a*(m_4 + m_b)**2*cos(theta(t)) + 7000000.0**cos(0.5*theta(t))*e_v*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*sin(theta(t))*Derivative(theta(t), t)**2 + 7000000.0**cos(0.5*theta(t))*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*s_d(t)*sin(theta(t)) + 7000000.0**cos(0.5*theta(t))*f_1*l_2**3*m_a*(m_4 + m_b)**2*s_d(t)*sin(theta(t)) + 7000000.0**cos(0.5*theta(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*s_d(t)*cos(theta(t))*Derivative(theta(t), t)**2 + 2.0*7000000.0**cos(0.5*theta(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*sin(theta(t))*Derivative(s_d(t), t)*Derivative(theta(t), t) + 7000000.0**cos(0.5*theta(t))*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*Derivative(s_d(t), t)**2 + A*l_2*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*cos(theta(t)) + A*l_2*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*cos(theta(t)) - A*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*s_d(t) - A*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*s_d(t))/(7000000.0**cos(0.5*theta(t))*(1.0*7000000**cos(theta(t)/2)*m_4 + 1.0*7000000**cos(theta(t)/2)*m_b)*(k_r**2*l_2**2*m_2*(m_4 + m_b)**2*(e_v*cos(theta(t)) - s_d(t)*sin(theta(t)))**2 + l_2**4*m_a*(m_4 + m_b)**2*(e_v*cos(theta(t)) - s_d(t)*sin(theta(t)))**2 + m_4*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(theta(t)) - s_d(t))**2 + m_b*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(theta(t)) - s_d(t))**2)) - 1.0*A/(1.0*7000000**cos(theta(t)/2)*m_4 + 1.0*7000000**cos(theta(t)/2)*m_b)]

# %%
zarr = sym.Array([sym.Function('z1')(t),sym.Function('z2')(t),sym.Function('z3')(t),sym.Function('z4')(t)])
d1zarr = sym.diff(zarr,t)
display(zarr,d1zarr)
# Out:
# [z1(t), z2(t), z3(t), z4(t)]
# [Derivative(z1(t), t), Derivative(z2(t), t), Derivative(z3(t), t), Derivative(z4(t), t)]

# %%
nd2w = d2w2.subs([(b1[0],zarr[2]),(b1[1],zarr[3]), (a1[0],zarr[0]), (a1[1],zarr[1])])
nd2w
# Out:
# [1.0*f_1/(1.0*k_r**2*m_2 + 1.0*l_2**2*m_a) - 0.5*(2*l_2*(-e_v + l_2*sin(z1(t)))*cos(z1(t)) - 2*l_2*(l_2*cos(z1(t)) - z2(t))*sin(z1(t)))*(-7000000.0**cos(0.5*z1(t))*e_v*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*cos(z1(t)) - 7000000.0**cos(0.5*z1(t))*e_v*f_1*l_2**3*m_a*(m_4 + m_b)**2*cos(z1(t)) + 7000000.0**cos(0.5*z1(t))*e_v*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z3(t)**2*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*z2(t)*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*f_1*l_2**3*m_a*(m_4 + m_b)**2*z2(t)*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z2(t)*z3(t)**2*cos(z1(t)) + 2.0*7000000.0**cos(0.5*z1(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z3(t)*z4(t)*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z4(t)**2 + A*l_2*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*cos(z1(t)) + A*l_2*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*cos(z1(t)) - A*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*z2(t) - A*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*z2(t))/(7000000.0**cos(0.5*z1(t))*(1.0*k_r**2*m_2 + 1.0*l_2**2*m_a)*(k_r**2*l_2**2*m_2*(m_4 + m_b)**2*(e_v*cos(z1(t)) - z2(t)*sin(z1(t)))**2 + l_2**4*m_a*(m_4 + m_b)**2*(e_v*cos(z1(t)) - z2(t)*sin(z1(t)))**2 + m_4*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(z1(t)) - z2(t))**2 + m_b*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(z1(t)) - z2(t))**2)), -0.5*7000000**cos(z1(t)/2)*(-2*l_2*cos(z1(t)) + 2*z2(t))*(-7000000.0**cos(0.5*z1(t))*e_v*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*cos(z1(t)) - 7000000.0**cos(0.5*z1(t))*e_v*f_1*l_2**3*m_a*(m_4 + m_b)**2*cos(z1(t)) + 7000000.0**cos(0.5*z1(t))*e_v*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z3(t)**2*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*z2(t)*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*f_1*l_2**3*m_a*(m_4 + m_b)**2*z2(t)*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z2(t)*z3(t)**2*cos(z1(t)) + 2.0*7000000.0**cos(0.5*z1(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z3(t)*z4(t)*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z4(t)**2 + A*l_2*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*cos(z1(t)) + A*l_2*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*cos(z1(t)) - A*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*z2(t) - A*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*z2(t))/(7000000.0**cos(0.5*z1(t))*(1.0*7000000**cos(z1(t)/2)*m_4 + 1.0*7000000**cos(z1(t)/2)*m_b)*(k_r**2*l_2**2*m_2*(m_4 + m_b)**2*(e_v*cos(z1(t)) - z2(t)*sin(z1(t)))**2 + l_2**4*m_a*(m_4 + m_b)**2*(e_v*cos(z1(t)) - z2(t)*sin(z1(t)))**2 + m_4*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(z1(t)) - z2(t))**2 + m_b*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(z1(t)) - z2(t))**2)) - 1.0*A/(1.0*7000000**cos(z1(t)/2)*m_4 + 1.0*7000000**cos(z1(t)/2)*m_b)]

# %%
rhs = sym.Array([zarr[2],zarr[3],nd2w[0],nd2w[1]])
rhs
# Out:
# [z3(t), z4(t), 1.0*f_1/(1.0*k_r**2*m_2 + 1.0*l_2**2*m_a) - 0.5*(2*l_2*(-e_v + l_2*sin(z1(t)))*cos(z1(t)) - 2*l_2*(l_2*cos(z1(t)) - z2(t))*sin(z1(t)))*(-7000000.0**cos(0.5*z1(t))*e_v*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*cos(z1(t)) - 7000000.0**cos(0.5*z1(t))*e_v*f_1*l_2**3*m_a*(m_4 + m_b)**2*cos(z1(t)) + 7000000.0**cos(0.5*z1(t))*e_v*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z3(t)**2*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*z2(t)*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*f_1*l_2**3*m_a*(m_4 + m_b)**2*z2(t)*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z2(t)*z3(t)**2*cos(z1(t)) + 2.0*7000000.0**cos(0.5*z1(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z3(t)*z4(t)*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z4(t)**2 + A*l_2*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*cos(z1(t)) + A*l_2*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*cos(z1(t)) - A*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*z2(t) - A*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*z2(t))/(7000000.0**cos(0.5*z1(t))*(1.0*k_r**2*m_2 + 1.0*l_2**2*m_a)*(k_r**2*l_2**2*m_2*(m_4 + m_b)**2*(e_v*cos(z1(t)) - z2(t)*sin(z1(t)))**2 + l_2**4*m_a*(m_4 + m_b)**2*(e_v*cos(z1(t)) - z2(t)*sin(z1(t)))**2 + m_4*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(z1(t)) - z2(t))**2 + m_b*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(z1(t)) - z2(t))**2)), -0.5*7000000**cos(z1(t)/2)*(-2*l_2*cos(z1(t)) + 2*z2(t))*(-7000000.0**cos(0.5*z1(t))*e_v*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*cos(z1(t)) - 7000000.0**cos(0.5*z1(t))*e_v*f_1*l_2**3*m_a*(m_4 + m_b)**2*cos(z1(t)) + 7000000.0**cos(0.5*z1(t))*e_v*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z3(t)**2*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*f_1*k_r**2*l_2*m_2*(m_4 + m_b)**2*z2(t)*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*f_1*l_2**3*m_a*(m_4 + m_b)**2*z2(t)*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z2(t)*z3(t)**2*cos(z1(t)) + 2.0*7000000.0**cos(0.5*z1(t))*l_2*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z3(t)*z4(t)*sin(z1(t)) + 7000000.0**cos(0.5*z1(t))*(m_4 + m_b)**2*(k_r**2*m_2 + l_2**2*m_a)**2*z4(t)**2 + A*l_2*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*cos(z1(t)) + A*l_2*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*cos(z1(t)) - A*m_4*(k_r**2*m_2 + l_2**2*m_a)**2*z2(t) - A*m_b*(k_r**2*m_2 + l_2**2*m_a)**2*z2(t))/(7000000.0**cos(0.5*z1(t))*(1.0*7000000**cos(z1(t)/2)*m_4 + 1.0*7000000**cos(z1(t)/2)*m_b)*(k_r**2*l_2**2*m_2*(m_4 + m_b)**2*(e_v*cos(z1(t)) - z2(t)*sin(z1(t)))**2 + l_2**4*m_a*(m_4 + m_b)**2*(e_v*cos(z1(t)) - z2(t)*sin(z1(t)))**2 + m_4*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(z1(t)) - z2(t))**2 + m_b*(k_r**2*m_2 + l_2**2*m_a)**2*(l_2*cos(z1(t)) - z2(t))**2)) - 1.0*A/(1.0*7000000**cos(z1(t)/2)*m_4 + 1.0*7000000**cos(z1(t)/2)*m_b)]

# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
#crank = 4kg
#reciprocating element m4 = 3kg
#ma = 3kg
#mb = 2kg
#torque f1 =100

varr = [(ev,0),(m2,4),(ma,3),(m4,3),(mb,2),(l2,0.2),(l3,0.4),(kr,0.2),(f1,100),(A,0.3)]

def dydt(zz,tval):
    temp = rhs.subs(varr)
    return temp.subs([(zarr[0],zz[0]),(zarr[1],zz[1]),(zarr[2],zz[2]),(zarr[3],zz[3]),(t,tval)])

# %%
nstp = 800
tout = np.linspace(0,8,nstp)
yinit = [np.pi/2,(sym.sqrt(l3**2-(l2-ev)**2)).subs(varr),0,0]
yinit
# Out:
# [1.5707963267948966, 0.346410161513776, 0, 0]

# %%
sol = odeint(dydt,yinit,tout)

# %%
plt.plot(tout,sol[:,0],'b')
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
plt.plot(tout,sol[:,1],'r')
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
plt.plot(tout,sol[:,2],'m')
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
plt.plot(tout,sol[:,3],'g')
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
zfa = (zf.subs(varr)).subs([(b1[0],zarr[2]),(b1[1],zarr[3]),(a1[0],zarr[0]),(a1[1],zarr[1])])
subarr = [[(zarr[j], sol[i,j]) for j in range(4)] for i in range(nstp)]
coarr = [(sym.sqrt(zfa).subs(subarr[i])-l3.subs(varr)) for i in range(nstp)]
plt.plot(tout, coarr, 'b')

# %%
intf = ((kv*co).subs(varr)).subs([(b1[0],zarr[2]),(b1[1],zarr[3]),(a1[0],zarr[0]),(a1[1],zarr[1])])
intfarr = [(intf.subs(subarr[i])) for i in range(nstp)]

# %%
plt.plot(tout,intfarr, 'r')

# %%
angarr = [((rhs[2].subs(varr)).subs(subarr[i])) for i in range(nstp)]
slidearr =[((rhs[3].subs(varr)).subs(subarr[i])) for i in range(nstp)]

# %%
plt.plot(tout,angarr,'r')

# %%
plt.plot(tout,slidearr,'b')

# %%
zarr2 = sym.Array([sym.Function('z5')(t),sym.Function('z6')(t),sym.Function('z7')(t),sym.Function('z8')(t)])

# %%
rhsv = np.array([(rhs.subs(varr)).subs(subarr[i]) for i in range(nstp)])

# %%
fullarr = [[(zarr[j], sol[i,j]) for j in range(4)] + [(zarr2[j], rhsv[i,j]) for j in range(4)] for i in range(nstp)]

# %%
fullarr

# %%
rho2,Ox,Oy, N = sym.symbols('rho_2, O_x,O_y,N')
pG2 = rho2*sym.Array([sym.cos(theta), sym.sin(theta)])
ps = sym.Array([sd,ev])
ps
# Out:
# [s_d(t), e_v]

# %%
apG2 = sym.diff(pG2,[t,2])
aps = sym.diff(ps,[t,2])
aps
# Out:
# [Derivative(s_d(t), (t, 2)), 0]

# %%
teqm = (m2*apG2+m4*aps-sym.Array([Ox-7000000**(sym.sin((theta-sym.pi)/2))*A,Oy+N])).subs([(b1[0],zarr[2]),(b1[1],zarr[3]),(a1[0],zarr[0]),(a1[1],zarr[1])])
teqm
# Out:
# [-O_x - m_2*rho_2*(z3(t)**2*cos(z1(t)) + sin(z1(t))*Derivative(z3(t), t)) + m_4*Derivative(z4(t), t) + A/7000000**cos(z1(t)/2), -N - O_y + m_2*rho_2*(-z3(t)**2*sin(z1(t)) + cos(z1(t))*Derivative(z3(t), t))]

# %%
ps3d = sym.Array(np.append(ps,sym.Array([0])))
ps3d
d1ps3d = sym.diff(ps3d,t)

Ho = (m2*kr**2*b1[0]+np.cross(ps3d,m4*d1ps3d)[2]).subs([(b1[0],zarr[2]),(b1[1],zarr[3]),(a1[0],zarr[0]),(a1[1],zarr[1])])
reqm = (sym.diff(Ho,t)-f1-sd*N-ev*(7000000**(sym.sin((theta-sym.pi)/2))*A)).subs([(b1[0],zarr[2]),(b1[1],zarr[3]),(a1[0],zarr[0]),(a1[1],zarr[1])])
reqm
# Out:
# -N*z2(t) - e_v*m_4*Derivative(z4(t), t) - f_1 + k_r**2*m_2*Derivative(z3(t), t) - A*e_v/7000000**cos(z1(t)/2)

# %%
display(d1ps3d)
# Out:
# [Derivative(s_d(t), t), 0, 0]

# %%
display(Ho)
# Out:
# -e_v*m_4*z4(t) + k_r**2*m_2*z3(t)

# %%
Ny = sym.solve(reqm,N)[0]
Ny = Ny.subs([(sym.diff(zarr[2],t),zarr2[2]),(sym.diff(zarr[3],t),zarr2[3])]).subs(varr)
# [(zarr[j], sol[i,j]) for j in range(4)]
Nyarr = [(Ny.subs(fullarr[i])) for i in range(nstp)]
plt.plot(tout,Nyarr)
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
teqm[0]
# Out:
# -O_x - m_2*rho_2*(z3(t)**2*cos(z1(t)) + sin(z1(t))*Derivative(z3(t), t)) + m_4*Derivative(z4(t), t) + A/7000000**cos(z1(t)/2)

# %%
Rx = sym.solve(teqm[0],Ox)[0]
Rx = Rx.subs([(sym.diff(zarr[2],t),zarr2[2]),(sym.diff(zarr[3],t),zarr2[3])]).subs(varr).subs([(rho2,0.15)])
Rxarr = [(Rx.subs(fullarr[i])) for i in range(nstp)]
plt.plot(tout,Rxarr)
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
Ry = sym.solve(teqm[1],Oy)[0]
Ry = Ry.subs([(sym.diff(zarr[2],t),zarr2[2]),(sym.diff(zarr[3],t),zarr2[3])]).subs(varr).subs([(rho2,0.15)])
Ryarr = [(Ry.subs(fullarr[i]).subs(N,Nyarr[i])) for i in range(nstp)]
plt.plot(tout,Ryarr)
plt.xlim(0,2)
# Out:
# (0.0, 2.0)
